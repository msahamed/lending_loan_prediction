# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %% [markdown]
# ### Read data

# %%
df1 = pd.read_csv('./data/LoanStats_securev1_2017Q1.csv', skiprows=[0])
df2 = pd.read_csv('./data/LoanStats_securev1_2017Q2.csv', skiprows=[0])
df3 = pd.read_csv('./data/LoanStats_securev1_2017Q3.csv', skiprows=[0])
df4 = pd.read_csv('./data/LoanStats3c_securev1_2014.csv', skiprows=[0])
df5 = pd.read_csv('./data/LoanStats3d_securev1_2015.csv', skiprows=[0])

# %% [markdown]
# ### Check if all the datasets have same column

# %%
columns = np.dstack((list(df1.columns), list(df2.columns), list(df3.columns), list(df4.columns), list(df5.columns)))

# %%
coldf = pd.DataFrame(columns[0])

# %%
# coldf.head()

# %%
df = pd.concat([df1, df2, df3, df4, df5])

# %% [markdown]
# ### Get familiar with data

# %%
df.shape
# Out:
# (981665, 151)

# %%
print(list(df.columns))
# Out:
# ['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length', 'home_ownership', 'annual_inc', 'verification_status', 'issue_d', 'loan_status', 'pymnt_plan', 'url', 'desc', 'purpose', 'title', 'zip_code', 'addr_state', 'dti', 'delinq_2yrs', 'earliest_cr_line', 'fico_range_low', 'fico_range_high', 'inq_last_6mths', 'mths_since_last_delinq', 'mths_since_last_record', 'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc', 'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries', 'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt', 'next_pymnt_d', 'last_credit_pull_d', 'last_fico_range_high', 'last_fico_range_low', 'collections_12_mths_ex_med', 'mths_since_last_major_derog', 'policy_code', 'application_type', 'annual_inc_joint', 'dti_joint', 'verification_status_joint', 'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m', 'open_act_il', 'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il', 'total_bal_il', 'il_util', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc', 'all_util', 'total_rev_hi_lim', 'inq_fi', 'total_cu_tl', 'inq_last_12m', 'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util', 'chargeoff_within_12_mths', 'delinq_amnt', 'mo_sin_old_il_acct', 'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl', 'mort_acc', 'mths_since_recent_bc', 'mths_since_recent_bc_dlq', 'mths_since_recent_inq', 'mths_since_recent_revol_delinq', 'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_actv_rev_tl', 'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl', 'num_rev_accts', 'num_rev_tl_bal_gt_0', 'num_sats', 'num_tl_120dpd_2m', 'num_tl_30dpd', 'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq', 'percent_bc_gt_75', 'pub_rec_bankruptcies', 'tax_liens', 'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit', 'total_il_high_credit_limit', 'revol_bal_joint', 'sec_app_fico_range_low', 'sec_app_fico_range_high', 'sec_app_earliest_cr_line', 'sec_app_inq_last_6mths', 'sec_app_mort_acc', 'sec_app_open_acc', 'sec_app_revol_util', 'sec_app_open_act_il', 'sec_app_num_rev_accts', 'sec_app_chargeoff_within_12_mths', 'sec_app_collections_12_mths_ex_med', 'sec_app_mths_since_last_major_derog', 'hardship_flag', 'hardship_type', 'hardship_reason', 'hardship_status', 'deferral_term', 'hardship_amount', 'hardship_start_date', 'hardship_end_date', 'payment_plan_start_date', 'hardship_length', 'hardship_dpd', 'hardship_loan_status', 'orig_projected_additional_accrued_interest', 'hardship_payoff_balance_amount', 'hardship_last_payment_amount', 'disbursement_method', 'debt_settlement_flag', 'debt_settlement_flag_date', 'settlement_status', 'settlement_date', 'settlement_amount', 'settlement_percentage', 'settlement_term']

# %%
df.head(5)
# Out:
#           id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  104046719        NaN    14000.0      14000.0          14000.0   36 months
# 1  104048967        NaN     5000.0       5000.0           5000.0   36 months
# 2  104028593        NaN     4600.0       4600.0           4600.0   36 months
# 3  104046702        NaN    14000.0      14000.0          14000.0   60 months
# 4  104280113        NaN    15000.0      15000.0          15000.0   36 months
#
#   int_rate  installment grade sub_grade                  emp_title emp_length  \
# 0   15.99%       492.13     C        C5             Project Leader  10+ years
# 1   25.49%       200.10     E        E4                      Pilot  10+ years
# 2   11.39%       151.45     B        B3           cable technician    4 years
# 3   12.74%       316.69     C        C1            Specialty Sales    4 years
# 4    5.32%       451.73     A        A1  Executive Account Manager  10+ years
#
#   home_ownership  annual_inc verification_status   issue_d loan_status  \
# 0       MORTGAGE     82000.0     Source Verified  Mar-2017     Current
# 1       MORTGAGE    215000.0     Source Verified  Mar-2017     Current
# 2           RENT     44470.0        Not Verified  Mar-2017     Current
# 3            OWN     40000.0        Not Verified  Mar-2017     Current
# 4       MORTGAGE    182000.0        Not Verified  Mar-2017     Current
#
#   pymnt_plan                                                url desc  \
# 0          n  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 1          n  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 2          n  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 3          n  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 4          n  https://lendingclub.com/browse/loanDetail.acti...  NaN
#
#               purpose                    title zip_code addr_state    dti  \
# 0         credit_card  Credit card refinancing    672xx         KS  31.07
# 1  debt_consolidation       Debt consolidation    067xx         CT   6.06
# 2         credit_card  Credit card refinancing    066xx         CT  13.43
# 3         credit_card  Credit card refinancing    926xx         CA  17.48
# 4  debt_consolidation       Debt consolidation    751xx         TX   9.35
#
#    delinq_2yrs earliest_cr_line  fico_range_low  fico_range_high  \
# 0          0.0         May-1996           725.0            729.0
# 1          0.0         Jan-2004           765.0            769.0
# 2          0.0         Dec-2003           770.0            774.0
# 3          0.0         Feb-1974           715.0            719.0
# 4          0.0         Nov-1974           740.0            744.0
#
#    inq_last_6mths  mths_since_last_delinq  mths_since_last_record  open_acc  \
# 0             0.0                     NaN                     NaN      18.0
# 1             4.0                     NaN                     NaN      11.0
# 2             1.0                     NaN                     NaN       7.0
# 3             0.0                     NaN                     NaN      10.0
# 4             0.0                     NaN                     NaN      13.0
#
#    pub_rec  revol_bal revol_util  total_acc initial_list_status  out_prncp  \
# 0      0.0    69578.0      63.2%       31.0                   w   11438.26
# 1      0.0     8678.0      18.8%       16.0                   f    4190.59
# 2      0.0     5400.0      19.1%       11.0                   w    3708.50
# 3      0.0    25787.0      46.2%       23.0                   w   12604.51
# 4      0.0    34623.0      33.7%       32.0                   w   11869.91
#
#    out_prncp_inv  total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 0       11438.26      3912.17          3912.17          2561.74
# 1        4190.59      1586.64          1586.64           809.41
# 2        3708.50      1205.78          1205.78           891.50
# 3       12604.51      2585.32          2585.32          1395.49
# 4       11869.91      3604.97          3604.97          3130.09
#
#    total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee  \
# 0        1350.43                 0.0         0.0                      0.0
# 1         777.23                 0.0         0.0                      0.0
# 2         314.28                 0.0         0.0                      0.0
# 3        1189.83                 0.0         0.0                      0.0
# 4         474.88                 0.0         0.0                      0.0
#
#   last_pymnt_d  last_pymnt_amnt next_pymnt_d last_credit_pull_d  \
# 0     Dec-2017           492.13     Jan-2018           Dec-2017
# 1     Dec-2017           200.10     Jan-2018           Dec-2017
# 2     Dec-2017           151.45     Jan-2018           Dec-2017
# 3     Dec-2017           316.69     Jan-2018           Dec-2017
# 4     Dec-2017           451.73     Jan-2018           Dec-2017
#
#    last_fico_range_high  last_fico_range_low  collections_12_mths_ex_med  \
# 0                 714.0                710.0                         0.0
# 1                 779.0                775.0                         0.0
# 2                 769.0                765.0                         0.0
# 3                 714.0                710.0                         0.0
# 4                 734.0                730.0                         0.0
#
#    mths_since_last_major_derog  policy_code application_type  \
# 0                          NaN          1.0       Individual
# 1                          NaN          1.0       Individual
# 2                          NaN          1.0       Individual
# 3                          NaN          1.0       Individual
# 4                          NaN          1.0       Individual
#
#    annual_inc_joint  dti_joint verification_status_joint  acc_now_delinq  \
# 0               NaN        NaN                       NaN             0.0
# 1               NaN        NaN                       NaN             0.0
# 2               NaN        NaN                       NaN             0.0
# 3               NaN        NaN                       NaN             0.0
# 4               NaN        NaN                       NaN             0.0
#
#    tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  open_il_12m  \
# 0           0.0     202617.0          0.0          3.0          0.0
# 1           0.0      44754.0          1.0          3.0          2.0
# 2           0.0       9625.0          1.0          1.0          0.0
# 3           0.0      25787.0          2.0          0.0          0.0
# 4           0.0     233521.0          0.0          1.0          0.0
#
#    open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 0          1.0                22.0       34430.0     57.0          0.0
# 1          4.0                 7.0       35832.0     68.0          2.0
# 2          1.0                22.0        4225.0     36.0          2.0
# 3          0.0               129.0           0.0      NaN          5.0
# 4          1.0                24.0        2667.0     59.0          2.0
#
#    open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  total_cu_tl  \
# 0          2.0     13686.0      61.0          110037.0     0.0          9.0
# 1          2.0      8659.0      27.0           46200.0     2.0          0.0
# 2          4.0      4670.0      24.0           28300.0     0.0          0.0
# 3          7.0      8549.0      46.0           55800.0     0.0          3.0
# 4          2.0     12503.0      42.0          102600.0     1.0          6.0
#
#    inq_last_12m  acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  bc_util  \
# 0           0.0                   3.0      11257.0         29762.0     63.4
# 1           6.0                   6.0       4069.0         37522.0     18.8
# 2           1.0                   5.0       1375.0          9610.0     33.7
# 3           0.0                   7.0       2579.0         27153.0     48.3
# 4           0.0                   4.0      17963.0         55203.0     26.0
#
#    chargeoff_within_12_mths  delinq_amnt  mo_sin_old_il_acct  \
# 0                       0.0          0.0               140.0
# 1                       0.0          0.0                83.0
# 2                       0.0          0.0                77.0
# 3                       0.0          0.0               129.0
# 4                       0.0          0.0                92.0
#
#    mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  \
# 0                 250.0                   13.0            13.0       6.0
# 1                  87.0                    5.0             5.0       0.0
# 2                 159.0                    1.0             1.0       0.0
# 3                 517.0                    1.0             1.0       1.0
# 4                 508.0                    8.0             8.0       5.0
#
#    mths_since_recent_bc  mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 0                  13.0                       NaN                   13.0
# 1                   5.0                       NaN                    0.0
# 2                   7.0                       NaN                    1.0
# 3                   2.0                       NaN                   23.0
# 4                   8.0                       NaN                   17.0
#
#    mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 0                             NaN                    0.0             7.0
# 1                             NaN                    0.0             2.0
# 2                             NaN                    0.0             2.0
# 3                             NaN                    0.0             7.0
# 4                             NaN                    0.0             3.0
#
#    num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 0              9.0          8.0       13.0        4.0           14.0
# 1              2.0          7.0        8.0        7.0            7.0
# 2              3.0          3.0        4.0        2.0            6.0
# 3              9.0          8.0       13.0        1.0           10.0
# 4              6.0          7.0       11.0        9.0           10.0
#
#    num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 0           21.0                  9.0      18.0               0.0
# 1            8.0                  2.0      11.0               0.0
# 2            9.0                  3.0       7.0               0.0
# 3           21.0                  9.0      10.0               0.0
# 4           16.0                  6.0      13.0               0.0
#
#    num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 0           0.0                 0.0                 0.0           100.0
# 1           0.0                 0.0                 4.0           100.0
# 2           0.0                 0.0                 2.0           100.0
# 3           0.0                 0.0                 5.0           100.0
# 4           0.0                 0.0                 2.0           100.0
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0              25.0                   0.0        0.0         286204.0
# 1               0.0                   0.0        0.0         100763.0
# 2               0.0                   0.0        0.0          40000.0
# 3              37.5                   0.0        0.0          55800.0
# 4               0.0                   0.0        0.0         325464.0
#
#    total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0           104008.0         81400.0                     60167.0
# 1            44754.0         46200.0                     49814.0
# 2             9625.0         14500.0                     11700.0
# 3            25787.0         52500.0                         0.0
# 4            50766.0         74600.0                      4508.0
#
#    revol_bal_joint  sec_app_fico_range_low  sec_app_fico_range_high  \
# 0              NaN                     NaN                      NaN
# 1              NaN                     NaN                      NaN
# 2              NaN                     NaN                      NaN
# 3              NaN                     NaN                      NaN
# 4              NaN                     NaN                      NaN
#
#   sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# 0                      NaN                     NaN               NaN
# 1                      NaN                     NaN               NaN
# 2                      NaN                     NaN               NaN
# 3                      NaN                     NaN               NaN
# 4                      NaN                     NaN               NaN
#
#    sec_app_open_acc  sec_app_revol_util  sec_app_open_act_il  \
# 0               NaN                 NaN                  NaN
# 1               NaN                 NaN                  NaN
# 2               NaN                 NaN                  NaN
# 3               NaN                 NaN                  NaN
# 4               NaN                 NaN                  NaN
#
#    sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# 0                    NaN                               NaN
# 1                    NaN                               NaN
# 2                    NaN                               NaN
# 3                    NaN                               NaN
# 4                    NaN                               NaN
#
#    sec_app_collections_12_mths_ex_med  sec_app_mths_since_last_major_derog  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
#
#   hardship_flag hardship_type hardship_reason hardship_status  deferral_term  \
# 0             N           NaN             NaN             NaN            NaN
# 1             N           NaN             NaN             NaN            NaN
# 2             N           NaN             NaN             NaN            NaN
# 3             N           NaN             NaN             NaN            NaN
# 4             N           NaN             NaN             NaN            NaN
#
#    hardship_amount hardship_start_date hardship_end_date  \
# 0              NaN                 NaN               NaN
# 1              NaN                 NaN               NaN
# 2              NaN                 NaN               NaN
# 3              NaN                 NaN               NaN
# 4              NaN                 NaN               NaN
#
#   payment_plan_start_date  hardship_length  hardship_dpd hardship_loan_status  \
# 0                     NaN              NaN           NaN                  NaN
# 1                     NaN              NaN           NaN                  NaN
# 2                     NaN              NaN           NaN                  NaN
# 3                     NaN              NaN           NaN                  NaN
# 4                     NaN              NaN           NaN                  NaN
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                         NaN                             NaN
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
#
#    hardship_last_payment_amount disbursement_method debt_settlement_flag  \
# 0                           NaN                Cash                    N
# 1                           NaN                Cash                    N
# 2                           NaN                Cash                    N
# 3                           NaN                Cash                    N
# 4                           NaN                Cash                    N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#    settlement_amount  settlement_percentage  settlement_term
# 0                NaN                    NaN              NaN
# 1                NaN                    NaN              NaN
# 2                NaN                    NaN              NaN
# 3                NaN                    NaN              NaN
# 4                NaN                    NaN              NaN

# %%
df.dtypes.sort_values().to_frame('feature_type').groupby(by = 'feature_type').size().to_frame('count').reset_index()
# Out:
#   feature_type  count
# 0      float64    111
# 1       object     40

# %% [markdown]
# ### Select data with loan_status either Fully Paid or Charged Off

# %%
df.loan_status.value_counts()
# Out:
# Current               500937
# Fully Paid            358629
# Charged Off            99099
# Late (31-120 days)     13203
# In Grace Period         6337
# Late (16-30 days)       3414
# Default                   36
# Name: loan_status, dtype: int64

# %%
df = df.loc[(df['loan_status'].isin(['Fully Paid', 'Charged Off']))]

# %%
df.shape
# Out:
# (457728, 151)

# %% [markdown]
# ### Feature selections and clean

# %% [markdown]
# ### Find the missing columns and their types

# %%
df_dtypes = pd.merge(df.isnull().sum(axis = 0).sort_values().to_frame('missing_value').reset_index(),
         df.dtypes.to_frame('feature_type').reset_index(),
         on = 'index',
         how = 'inner')

# %%
df_dtypes.sort_values(['missing_value', 'feature_type'])
# Out:
#                                           index  missing_value feature_type
# 1                               tot_hi_cred_lim              0      float64
# 2                                   tot_cur_bal              0      float64
# 3                                  tot_coll_amt              0      float64
# 4                                acc_now_delinq              0      float64
# 5                             total_bal_ex_mort              0      float64
# 6                                total_bc_limit              0      float64
# 7                    total_il_high_credit_limit              0      float64
# 9                                   policy_code              0      float64
# 10                   collections_12_mths_ex_med              0      float64
# 11                          last_fico_range_low              0      float64
# 12                         last_fico_range_high              0      float64
# 14                                  num_bc_sats              0      float64
# 15                      collection_recovery_fee              0      float64
# 16                                   recoveries              0      float64
# 17                           total_rec_late_fee              0      float64
# 18                                    tax_liens              0      float64
# 19                                total_rec_int              0      float64
# 20                         pub_rec_bankruptcies              0      float64
# 21                           num_tl_op_past_12m              0      float64
# 22                              num_actv_rev_tl              0      float64
# 23                               num_actv_bc_tl              0      float64
# 24                        num_accts_ever_120_pd              0      float64
# 25                                     mort_acc              0      float64
# 26                               mo_sin_rcnt_tl              0      float64
# 27                        mo_sin_rcnt_rev_tl_op              0      float64
# 28                         mo_sin_old_rev_tl_op              0      float64
# 29                                  delinq_amnt              0      float64
# 30                     chargeoff_within_12_mths              0      float64
# 31                         acc_open_past_24mths              0      float64
# 32                                    num_il_tl              0      float64
# 33                                num_op_rev_tl              0      float64
# 34                             total_rev_hi_lim              0      float64
# 35                          num_rev_tl_bal_gt_0              0      float64
# 36                                     num_sats              0      float64
# 37                                 num_tl_30dpd              0      float64
# 38                           num_tl_90g_dpd_24m              0      float64
# 39                               pct_tl_nvr_dlq              0      float64
# 40                              total_rec_prncp              0      float64
# 41                              last_pymnt_amnt              0      float64
# 42                                  total_pymnt              0      float64
# 45                              total_pymnt_inv              0      float64
# 49                                   annual_inc              0      float64
# 53                                  installment              0      float64
# 56                              funded_amnt_inv              0      float64
# 57                                  funded_amnt              0      float64
# 58                                    loan_amnt              0      float64
# 63                                    num_bc_tl              0      float64
# 64                                out_prncp_inv              0      float64
# 65                                  delinq_2yrs              0      float64
# 66                                    out_prncp              0      float64
# 68                               fico_range_low              0      float64
# 69                              fico_range_high              0      float64
# 70                               inq_last_6mths              0      float64
# 72                                    total_acc              0      float64
# 73                                    revol_bal              0      float64
# 74                                      pub_rec              0      float64
# 75                                     open_acc              0      float64
# 0                                            id              0       object
# 8                              application_type              0       object
# 13                                hardship_flag              0       object
# 43                          disbursement_method              0       object
# 44                                          url              0       object
# 46                                  loan_status              0       object
# 47                                      issue_d              0       object
# 48                          verification_status              0       object
# 50                               home_ownership              0       object
# 51                                    sub_grade              0       object
# 52                                        grade              0       object
# 54                                     int_rate              0       object
# 55                                         term              0       object
# 59                         debt_settlement_flag              0       object
# 60                                      purpose              0       object
# 61                                     zip_code              0       object
# 62                                   pymnt_plan              0       object
# 67                             earliest_cr_line              0       object
# 71                          initial_list_status              0       object
# 76                                   addr_state              0       object
# 77                                num_rev_accts              1      float64
# 78                                  avg_cur_bal              6      float64
# 79                                          dti             21      float64
# 80                           last_credit_pull_d             26       object
# 81                                        title             62       object
# 82                                   revol_util            223       object
# 83                                 last_pymnt_d            731       object
# 84                         mths_since_recent_bc           4477      float64
# 85                               bc_open_to_buy           4772      float64
# 86                             percent_bc_gt_75           5036      float64
# 87                                      bc_util           5093      float64
# 88                           mo_sin_old_il_acct          13020      float64
# 89                             num_tl_120dpd_2m          18945      float64
# 90                                   emp_length          24885       object
# 91                                    emp_title          26043       object
# 92                        mths_since_recent_inq          40177      float64
# 93                       mths_since_last_delinq         223121      float64
# 94               mths_since_recent_revol_delinq         293406      float64
# 95                  mths_since_last_major_derog         323754      float64
# 96                     mths_since_recent_bc_dlq         338157      float64
# 97                       mths_since_last_record         371421      float64
# 98                                       inq_fi         417783      float64
# 99                                  total_cu_tl         417783      float64
# 100                                 open_acc_6m         417783      float64
# 101                                 open_act_il         417783      float64
# 102                                 open_il_12m         417783      float64
# 103                                 open_il_24m         417783      float64
# 104                                total_bal_il         417783      float64
# 105                                inq_last_12m         417783      float64
# 106                                 open_rv_12m         417783      float64
# 107                                 open_rv_24m         417783      float64
# 108                                  max_bal_bc         417783      float64
# 109                                    all_util         417786      float64
# 110                          mths_since_rcnt_il         418684      float64
# 111                                     il_util         423107      float64
# 112                                        desc         443599       object
# 113                           settlement_amount         449510      float64
# 117                             settlement_term         449510      float64
# 118                       settlement_percentage         449510      float64
# 114                             settlement_date         449510       object
# 115                           settlement_status         449510       object
# 116                   debt_settlement_flag_date         449510       object
# 120                                   dti_joint         456197      float64
# 121                            annual_inc_joint         456197      float64
# 119                   verification_status_joint         456197       object
# 123                             revol_bal_joint         456830      float64
# 124                     sec_app_fico_range_high         456830      float64
# 125          sec_app_collections_12_mths_ex_med         456830      float64
# 126                       sec_app_num_rev_accts         456830      float64
# 127                      sec_app_inq_last_6mths         456830      float64
# 128                            sec_app_mort_acc         456830      float64
# 129                            sec_app_open_acc         456830      float64
# 130                         sec_app_open_act_il         456830      float64
# 131                      sec_app_fico_range_low         456830      float64
# 132            sec_app_chargeoff_within_12_mths         456830      float64
# 122                    sec_app_earliest_cr_line         456830       object
# 133                          sec_app_revol_util         456847      float64
# 134         sec_app_mths_since_last_major_derog         457425      float64
# 135                hardship_last_payment_amount         457455      float64
# 136              hardship_payoff_balance_amount         457455      float64
# 138                                hardship_dpd         457455      float64
# 141                             hardship_amount         457455      float64
# 142                               deferral_term         457455      float64
# 146                             hardship_length         457455      float64
# 137                        hardship_loan_status         457455       object
# 139                     payment_plan_start_date         457455       object
# 140                           hardship_end_date         457455       object
# 143                             hardship_status         457455       object
# 144                             hardship_reason         457455       object
# 145                               hardship_type         457455       object
# 147                         hardship_start_date         457455       object
# 148  orig_projected_additional_accrued_interest         457677      float64
# 149                                   member_id         457728      float64
# 150                                next_pymnt_d         457728       object

# %% [markdown]
# #### 1. Check columns have more than $400000$ missing values ($\approx90\%$)

# %%
missing_df = df.isnull().sum(axis = 0).sort_values().to_frame('missing_value').reset_index()

# %%
miss_4000 = list(missing_df[missing_df.missing_value >= 400000]['index'])

# %%
print(len(miss_4000))
# Out:
# 53

# %%
print(sorted(miss_4000))
# Out:
# ['all_util', 'annual_inc_joint', 'debt_settlement_flag_date', 'deferral_term', 'desc', 'dti_joint', 'hardship_amount', 'hardship_dpd', 'hardship_end_date', 'hardship_last_payment_amount', 'hardship_length', 'hardship_loan_status', 'hardship_payoff_balance_amount', 'hardship_reason', 'hardship_start_date', 'hardship_status', 'hardship_type', 'il_util', 'inq_fi', 'inq_last_12m', 'max_bal_bc', 'member_id', 'mths_since_rcnt_il', 'next_pymnt_d', 'open_acc_6m', 'open_act_il', 'open_il_12m', 'open_il_24m', 'open_rv_12m', 'open_rv_24m', 'orig_projected_additional_accrued_interest', 'payment_plan_start_date', 'revol_bal_joint', 'sec_app_chargeoff_within_12_mths', 'sec_app_collections_12_mths_ex_med', 'sec_app_earliest_cr_line', 'sec_app_fico_range_high', 'sec_app_fico_range_low', 'sec_app_inq_last_6mths', 'sec_app_mort_acc', 'sec_app_mths_since_last_major_derog', 'sec_app_num_rev_accts', 'sec_app_open_acc', 'sec_app_open_act_il', 'sec_app_revol_util', 'settlement_amount', 'settlement_date', 'settlement_percentage', 'settlement_status', 'settlement_term', 'total_bal_il', 'total_cu_tl', 'verification_status_joint']

# %%
df.drop(miss_4000, axis = 1, inplace = True)

# %% [markdown]
# #### 2. Remove constant features

# %%
def find_constant_features(dataFrame):
    const_features = []
    for column in list(dataFrame.columns):
        if dataFrame[column].unique().size < 2:
            const_features.append(column)
    return const_features

# %%
const_features = find_constant_features(df)

# %%
const_features
# Out:
# ['pymnt_plan', 'out_prncp', 'out_prncp_inv', 'policy_code', 'hardship_flag']

# %%
df.hardship_flag.value_counts()
# Out:
# N    457728
# Name: hardship_flag, dtype: int64

# %%
df.drop(const_features, axis = 1, inplace = True)

# %% [markdown]
# #### 3. Remove Duplicate rows

# %%
df.shape
# Out:
# (457728, 93)

# %%
df.drop_duplicates(inplace= True)

# %%
df.shape
# Out:
# (457728, 93)

# %% [markdown]
# #### 4. Remove duplicate columns

# %%
def duplicate_columns(frame):
    groups = frame.columns.to_series().groupby(frame.dtypes).groups
    dups = []

    for t, v in groups.items():

        cs = frame[v].columns
        vs = frame[v]
        lcs = len(cs)

        for i in range(lcs):
            ia = vs.iloc[:,i].values
            for j in range(i+1, lcs):
                ja = vs.iloc[:,j].values
                if np.array_equal(ia, ja):
                    dups.append(cs[i])
                    break
    return dups

# %%
duplicate_cols = duplicate_columns(df)

# %%
duplicate_cols
# Out:
# ['loan_amnt']

# %%
df.shape
# Out:
# (457728, 93)

# %% [markdown]
# #### 5. Remove/process features manually

# %%
features_to_be_removed = []

# %%
def plot_feature(col_name, isContinuous):
    """
    Visualize a variable with and without faceting on the loan status.
    - col_name is the variable name in the dataframe
    - full_name is the full variable name
    - continuous is True if the variable is continuous, False otherwise
    """
    f, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12,3), dpi=90)
    
    # Plot without loan status
    if isContinuous:
        sns.distplot(df.loc[df[col_name].notnull(), col_name], kde=False, ax=ax1)
    else:
        sns.countplot(df[col_name], order=sorted(df[col_name].unique()), color='#5975A4', saturation=1, ax=ax1)
    ax1.set_xlabel(col_name)
    ax1.set_ylabel('Count')
    ax1.set_title(col_name)
    plt.xticks(rotation = 90)

    # Plot with loan status
    if isContinuous:
        sns.boxplot(x=col_name, y='loan_status', data=df, ax=ax2)
        ax2.set_ylabel('')
        ax2.set_title(col_name + ' by Loan Status')
    else:
        data = df.groupby(col_name)['loan_status'].value_counts(normalize=True).to_frame('proportion').reset_index()        
        sns.barplot(x = col_name, y = 'proportion', hue= "loan_status", data = data, saturation=1, ax=ax2)
        ax2.set_ylabel('Loan fraction')
        ax2.set_title('Loan status')
        plt.xticks(rotation = 90)
    ax2.set_xlabel(col_name)
    
    plt.tight_layout()

# %% [markdown]
# ### 0-10 features

# %%
df.iloc[0:5, 0: 10]
# Out:
#            id  loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 16  104190249     3600.0       3600.0           3600.0   36 months    7.49%
# 38  104190255    35000.0      35000.0          35000.0   60 months   25.49%
# 40  104170260    17000.0      17000.0          17000.0   36 months    7.49%
# 51  104046830    10000.0      10000.0          10000.0   36 months   11.49%
# 56  104220223     5000.0       5000.0           5000.0   36 months   14.99%
#
#     installment grade sub_grade                      emp_title
# 16       111.97     A        A4      Code/Compliance Inspector
# 38      1037.38     E        E4  Human Resource Specialist LER
# 40       528.73     A        A4         Air Traffic Controller
# 51       329.72     B        B5                General manager
# 56       173.31     C        C4                Lead Supervisor

# %%
len(df.loan_amnt.value_counts())
# Out:
# 1415

# %%
plot_feature('loan_amnt', True)

# %% [markdown]
# It looks like all loans are not unique. Certain amount appear several times. It may be the reason, company has some range or certain amount to lend

# %% [markdown]
# ##### Term feature

# %%
df.term = df.term.str.replace('months', '').astype(np.int)

# %%
df.term.value_counts()
# Out:
# 36    341042
# 60    116686
# Name: term, dtype: int64

# %%
plot_feature('term', False)

# %% [markdown]
# ##### interest rate

# %%
df.int_rate = df.int_rate.str.replace('%', '').astype(np.float32)

# %%
len(df.int_rate.value_counts())
# Out:
# 200

# %%
plot_feature('int_rate', True)

# %% [markdown]
# It looks like applicants who could not afford to pay back or were charged off had higher interest rate.

# %% [markdown]
# ##### grade and subgrade

# %%
df.grade.value_counts()
# Out:
# C    129972
# B    123078
# A     75560
# D     74329
# E     38835
# F     12509
# G      3445
# Name: grade, dtype: int64

# %%
df.sub_grade.value_counts()
# Out:
# C1    27783
# C2    27383
# B5    26522
# C3    26375
# B4    26218
# C4    25615
# B3    25569
# B2    22889
# C5    22816
# A5    22738
# B1    21880
# D1    19249
# A4    17546
# D2    16052
# D3    14561
# D4    13405
# A3    11973
# A2    11711
# A1    11592
# D5    11062
# E1    10364
# E2     9177
# E3     7538
# E4     6260
# E5     5496
# F1     3990
# F2     2804
# F3     2449
# F4     1883
# F5     1383
# G1     1121
# G2      864
# G3      603
# G4      461
# G5      396
# Name: sub_grade, dtype: int64

# %%
plot_feature('grade', False)

# %%
plot_feature('sub_grade', False)

# %% [markdown]
# It seems that grade and sub grade have same shape and relation with loan status. IN this case I would keep sub_grade, because it carries more information than the grade.

# %% [markdown]
# ##### emp_title

# %%
len(df.emp_title.value_counts())
# Out:
# 128310

# %% [markdown]
# It looks like emp_title has lots of unique value, which may not be strongly associated with predicted loan amount

# %%
features_to_be_removed.extend(['emp_title', 'id'])

# %% [markdown]
# #### 11-20 features

# %%
df.iloc[0:5, 6: 20]
# Out:
#     installment grade sub_grade                      emp_title emp_length  \
# 16       111.97     A        A4      Code/Compliance Inspector  10+ years
# 38      1037.38     E        E4  Human Resource Specialist LER  10+ years
# 40       528.73     A        A4         Air Traffic Controller  10+ years
# 51       329.72     B        B5                General manager  10+ years
# 56       173.31     C        C4                Lead Supervisor  10+ years
#
#    home_ownership  annual_inc verification_status   issue_d loan_status  \
# 16       MORTGAGE    120000.0        Not Verified  Mar-2017  Fully Paid
# 38       MORTGAGE    114000.0     Source Verified  Mar-2017  Fully Paid
# 40       MORTGAGE    120000.0        Not Verified  Mar-2017  Fully Paid
# 51            OWN    145000.0        Not Verified  Mar-2017  Fully Paid
# 56           RENT     68000.0        Not Verified  Mar-2017  Fully Paid
#
#                                                   url             purpose  \
# 16  https://lendingclub.com/browse/loanDetail.acti...               other
# 38  https://lendingclub.com/browse/loanDetail.acti...    home_improvement
# 40  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 51  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 56  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
#
#                  title zip_code
# 16               Other    467xx
# 38    Home improvement    224xx
# 40  Debt consolidation    840xx
# 51  Debt consolidation    087xx
# 56  Debt consolidation    945xx

# %% [markdown]
# ##### emp_length

# %%
df.emp_length.value_counts()
# Out:
# 10+ years    151369
# 2 years       41008
# < 1 year      36781
# 3 years       36372
# 1 year        29681
# 4 years       26812
# 5 years       26720
# 8 years       22753
# 7 years       22333
# 6 years       20774
# 9 years       18240
# Name: emp_length, dtype: int64

# %%
df.emp_length.fillna(value=0,inplace=True)
df['emp_length'].replace(to_replace='[^0-9]+', value='', inplace=True, regex=True)
df['emp_length'] = df['emp_length'].astype(int)

# %%
plot_feature('emp_length', False)

# %% [markdown]
# It looks like emp lenght is not good predictor to determine the loan status. Sicne number of loanees remain same with the employment length.

# %% [markdown]
# ##### home_ownership

# %%
df.home_ownership.value_counts()
# Out:
# MORTGAGE    228469
# RENT        181308
# OWN          47875
# ANY             75
# NONE             1
# Name: home_ownership, dtype: int64

# %%
plot_feature('home_ownership', False)

# %% [markdown]
# home_ownership is also not that much discreminatory

# %% [markdown]
# ##### verification_status

# %%
df.verification_status.value_counts()
# Out:
# Source Verified    187996
# Not Verified       135931
# Verified           133801
# Name: verification_status, dtype: int64

# %%
df.verification_status = df.verification_status.map(lambda x: 1 if x == 'Not Verified' else 0)

# %%
plot_feature('verification_status', False)

# %% [markdown]
# verification_status is somewhat discreminative in the sense that, among the loanes whose source was verified are more charged off which is a bit wired.

# %% [markdown]
# #### issue_d

# %%
df.issue_d.value_counts()
# Out:
# Oct-2014    33699
# Jul-2014    25974
# Jul-2015    23990
# Jan-2015    22750
# Oct-2015    22431
# Nov-2014    21186
# Apr-2015    20097
# Dec-2015    19106
# May-2015    17964
# Aug-2015    17492
# Apr-2014    17140
# May-2014    17133
# Aug-2014    16780
# Nov-2015    16540
# Jun-2015    15304
# Jun-2014    15207
# Mar-2015    14997
# Mar-2014    14988
# Feb-2015    14464
# Jan-2014    14464
# Feb-2014    13945
# Sep-2015    13838
# Sep-2014     9344
# Dec-2014     8283
# Jan-2017     5912
# Mar-2017     5008
# Feb-2017     4241
# May-2017     3644
# Apr-2017     3431
# Jun-2017     2849
# Jul-2017     2366
# Aug-2017     1863
# Sep-2017     1298
# Name: issue_d, dtype: int64

# %%
df['issue_month'] = pd.Series(df.issue_d).str.replace(r'-\d+', '')

# %%
plot_feature('issue_month', False)

# %% [markdown]
# It looks like people who borrowed in December, are more charged off than those who borrowed in other months.

# %%
df.issue_month = df.issue_month.astype("category", categories=np.unique(df.issue_month)).cat.codes

# %%
df.issue_month.value_counts()
# Out:
# 10    56130
# 5     52330
# 4     43126
# 0     40668
# 8     38741
# 9     37726
# 1     36135
# 7     34993
# 6     33360
# 3     32650
# 2     27389
# 11    24480
# Name: issue_month, dtype: int64

# %%
df['issue_year'] = pd.Series(df.issue_d).str.replace(r'\w+-', '').astype(np.int)

# %%
df.issue_year.value_counts()
# Out:
# 2015    218973
# 2014    208143
# 2017     30612
# Name: issue_year, dtype: int64

# %% [markdown]
# #### loan status

# %%
df.loan_status.value_counts()
# Out:
# Fully Paid     358629
# Charged Off     99099
# Name: loan_status, dtype: int64

# %%
df.loan_status = df.loan_status.map(lambda x: 1 if x == 'Charged Off' else 0)

# %% [markdown]
# #### url

# %%
features_to_be_removed.append('url')

# %% [markdown]
# #### purpose

# %%
df.purpose.value_counts()
# Out:
# debt_consolidation    276597
# credit_card           102367
# home_improvement       27628
# other                  22100
# major_purchase          8256
# medical                 4786
# small_business          4206
# car                     3963
# moving                  2954
# vacation                2755
# house                   1836
# renewable_energy         268
# wedding                   11
# educational                1
# Name: purpose, dtype: int64

# %%
plot_feature('purpose', False)

# %% [markdown]
# It looks like, purpose can be a good discrimnatory. For exmaple people who had a purpose for renewable energy are more charged off while people borrwed loan for car or educational purpose are less charged off.

# %% [markdown]
# #### title

# %%
len(df.title.value_counts())
# Out:
# 1935

# %%
features_to_be_removed.append('title')

# %% [markdown]
# #### zip_code

# %%
len(df.zip_code.value_counts())
# Out:
# 910

# %%
features_to_be_removed.append('zip_code')

# %% [markdown]
# ##### addr_state

# %%
df.addr_state.value_counts()
# Out:
# CA    67209
# TX    37406
# NY    36650
# FL    31741
# IL    17478
# NJ    16260
# PA    15857
# OH    14976
# GA    14691
# VA    13204
# NC    12875
# MI    12183
# AZ    11150
# MD    10692
# CO    10559
# MA    10188
# WA    10153
# MN     8392
# IN     7955
# TN     7405
# MO     7170
# NV     6881
# CT     6246
# WI     6011
# AL     5818
# OR     5805
# SC     5358
# LA     5336
# KY     4423
# OK     4122
# KS     3778
# UT     3603
# AR     3408
# NM     2671
# MS     2384
# HI     2333
# NH     2141
# RI     1983
# WV     1974
# MT     1319
# DE     1292
# DC     1204
# AK     1125
# WY     1038
# SD      943
# VT      941
# NE      732
# ME      291
# ND      280
# ID       93
# IA        1
# Name: addr_state, dtype: int64

# %%
plot_feature('addr_state', False)

# %% [markdown]
# addr_state can be a good discreminatory feature.

# %% [markdown]
# ##### dti

# %%
# plot_feature('dti', True)

# %% [markdown]
# ### 21 - 30 features

# %%
df.iloc[0:5, 15: 30]
# Out:
#     loan_status                                                url  \
# 16            0  https://lendingclub.com/browse/loanDetail.acti...
# 38            0  https://lendingclub.com/browse/loanDetail.acti...
# 40            0  https://lendingclub.com/browse/loanDetail.acti...
# 51            0  https://lendingclub.com/browse/loanDetail.acti...
# 56            0  https://lendingclub.com/browse/loanDetail.acti...
#
#                purpose               title zip_code addr_state    dti  \
# 16               other               Other    467xx         IN  18.90
# 38    home_improvement    Home improvement    224xx         VA  14.04
# 40  debt_consolidation  Debt consolidation    840xx         UT   8.41
# 51  debt_consolidation  Debt consolidation    087xx         NJ  13.31
# 56  debt_consolidation  Debt consolidation    945xx         CA  22.50
#
#     delinq_2yrs earliest_cr_line  fico_range_low  fico_range_high  \
# 16          0.0         Aug-1992           720.0            724.0
# 38          0.0         Nov-1998           660.0            664.0
# 40          0.0         Oct-2005           735.0            739.0
# 51          2.0         Sep-2005           705.0            709.0
# 56          0.0         Apr-2003           660.0            664.0
#
#     inq_last_6mths  mths_since_last_delinq  mths_since_last_record  open_acc
# 16             1.0                     NaN                    96.0      18.0
# 38             1.0                    30.0                     NaN      17.0
# 40             0.0                    72.0                    89.0       9.0
# 51             0.0                     8.0                     NaN      13.0
# 56             0.0                    27.0                     NaN       6.0

# %% [markdown]
# ##### earliest_cr_line

# %%
df['earliest_cr_year'] = df.earliest_cr_line.str.replace(r'\w+-', '').astype(np.int)

# %%
df['credit_history'] = np.absolute(df['issue_year']- df['earliest_cr_year'])

# %%
df.credit_history.value_counts()
# Out:
# 13    32959
# 14    32690
# 12    31406
# 15    29670
# 11    28940
# 16    26000
# 10    23389
# 17    21970
# 18    19927
# 19    19155
# 20    17403
# 9     17389
# 21    15139
# 8     15041
# 22    11740
# 7     11408
# 23     9530
# 24     9333
# 25     8890
# 26     7844
# 6      7647
# 27     6844
# 28     6125
# 5      5866
# 4      5559
# 29     5200
# 30     4842
# 31     4073
# 32     3320
# 33     2380
# 3      2078
# 34     1957
# 35     1799
# 36     1684
# 37     1535
# 38     1302
# 39      988
# 40      785
# 41      682
# 42      632
# 43      497
# 44      389
# 45      363
# 47      278
# 46      272
# 48      204
# 49      158
# 50      130
# 51       85
# 52       60
# 53       41
# 54       32
# 56       27
# 55       26
# 59       10
# 57        9
# 58        8
# 60        6
# 64        4
# 61        2
# 65        2
# 66        1
# 63        1
# 62        1
# 70        1
# Name: credit_history, dtype: int64

# %%
features_to_be_removed.extend(['issue_d', 'mths_since_last_delinq', 'mths_since_last_record', 'inq_last_6mths', 'mths_since_last_delinq', 'mths_since_last_record'])

# %% [markdown]
# ### 31 - 40 features

# %%
df.iloc[0:5, 25: 40]
# Out:
#     fico_range_high  inq_last_6mths  mths_since_last_delinq  \
# 16            724.0             1.0                     NaN
# 38            664.0             1.0                    30.0
# 40            739.0             0.0                    72.0
# 51            709.0             0.0                     8.0
# 56            664.0             0.0                    27.0
#
#     mths_since_last_record  open_acc  pub_rec  revol_bal revol_util  \
# 16                    96.0      18.0      1.0     5658.0      14.9%
# 38                     NaN      17.0      0.0    35694.0      74.8%
# 40                    89.0       9.0      1.0    15406.0      31.6%
# 51                     NaN      13.0      0.0     7936.0      31.9%
# 56                     NaN       6.0      0.0    10276.0      90.1%
#
#     total_acc initial_list_status   total_pymnt  total_pymnt_inv  \
# 16       33.0                   w   3765.098751          3765.10
# 38       31.0                   w  36875.078917         36875.08
# 40       34.0                   w  17282.802792         17282.80
# 51       30.0                   w  10365.368358         10365.37
# 56       18.0                   f   5168.906377          5168.91
#
#     total_rec_prncp  total_rec_int  total_rec_late_fee
# 16           3600.0         165.10                 0.0
# 38          35000.0        1875.08                 0.0
# 40          17000.0         282.80                 0.0
# 51          10000.0         365.37                 0.0
# 56           5000.0         168.91                 0.0

# %%
df.revol_util = df.revol_util.str.replace('%', '').astype(np.float32)

# %%
df.initial_list_status.value_counts()
# Out:
# w    259204
# f    198524
# Name: initial_list_status, dtype: int64

# %%
df.initial_list_status = df.initial_list_status.map(lambda x: 1 if x== 'w' else 0)

# %%
features_to_be_removed.extend(['total_pymnt', 'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee'])

# %% [markdown]
# ### 41 - 50 features

# %%
df.iloc[0:5, 35: 50]
# Out:
#      total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  \
# 16   3765.098751          3765.10           3600.0         165.10
# 38  36875.078917         36875.08          35000.0        1875.08
# 40  17282.802792         17282.80          17000.0         282.80
# 51  10365.368358         10365.37          10000.0         365.37
# 56   5168.906377          5168.91           5000.0         168.91
#
#     total_rec_late_fee  recoveries  collection_recovery_fee last_pymnt_d  \
# 16                 0.0         0.0                      0.0     Dec-2017
# 38                 0.0         0.0                      0.0     Jun-2017
# 40                 0.0         0.0                      0.0     Jun-2017
# 51                 0.0         0.0                      0.0     Aug-2017
# 56                 0.0         0.0                      0.0     Jun-2017
#
#     last_pymnt_amnt last_credit_pull_d  last_fico_range_high  \
# 16          2984.31           Dec-2017                 724.0
# 38         35565.10           Jun-2017                 709.0
# 40         16768.22           Dec-2017                 764.0
# 51          9388.98           Nov-2017                 734.0
# 56          5003.93           Dec-2017                 659.0
#
#     last_fico_range_low  collections_12_mths_ex_med  \
# 16                720.0                         0.0
# 38                705.0                         0.0
# 40                760.0                         0.0
# 51                730.0                         0.0
# 56                655.0                         0.0
#
#     mths_since_last_major_derog application_type
# 16                          NaN       Individual
# 38                         30.0       Individual
# 40                         75.0       Individual
# 51                         26.0       Individual
# 56                          NaN       Individual

# %%
df.application_type.value_counts()
# Out:
# Individual    456197
# Joint App       1531
# Name: application_type, dtype: int64

# %%
df.application_type = df.application_type.map(lambda x: 0 if x == 'Individual' else 1)

# %%
features_to_be_removed.extend(['recoveries', 'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt', 'last_credit_pull_d', 'last_fico_range_high', 'last_fico_range_low', 'collections_12_mths_ex_med', 'mths_since_last_major_derog'])

# %% [markdown]
# ### 51 - 60 features

# %%
df.iloc[0:5, 45: 60]
# Out:
#     last_fico_range_high  last_fico_range_low  collections_12_mths_ex_med  \
# 16                 724.0                720.0                         0.0
# 38                 709.0                705.0                         0.0
# 40                 764.0                760.0                         0.0
# 51                 734.0                730.0                         0.0
# 56                 659.0                655.0                         0.0
#
#     mths_since_last_major_derog  application_type  acc_now_delinq  \
# 16                          NaN                 0             0.0
# 38                         30.0                 0             0.0
# 40                         75.0                 0             0.0
# 51                         26.0                 0             0.0
# 56                          NaN                 0             0.0
#
#     tot_coll_amt  tot_cur_bal  total_rev_hi_lim  acc_open_past_24mths  \
# 16           0.0      36506.0           37900.0                  13.0
# 38           0.0     394086.0           47700.0                   2.0
# 40           0.0     290743.0           48800.0                   3.0
# 51           0.0     324984.0           24900.0                   8.0
# 56         531.0      36168.0           11400.0                   2.0
#
#     avg_cur_bal  bc_open_to_buy  bc_util  chargeoff_within_12_mths  \
# 16       2147.0          7980.0     11.3                       0.0
# 38      24630.0          1481.0     95.5                       0.0
# 40      32305.0         32394.0     32.2                       0.0
# 51      24999.0         11199.0     40.1                       0.0
# 56       6028.0          1124.0     90.1                       0.0
#
#     delinq_amnt
# 16          0.0
# 38          0.0
# 40          0.0
# 51          0.0
# 56          0.0

# %%
features_to_be_removed.extend([ 'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'total_rev_hi_lim', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util', 'chargeoff_within_12_mths', 'delinq_amnt'])

# %% [markdown]
# ### 61 - 70 features

# %%
df.iloc[0:5, 55: 70]
# Out:
#     avg_cur_bal  bc_open_to_buy  bc_util  chargeoff_within_12_mths  \
# 16       2147.0          7980.0     11.3                       0.0
# 38      24630.0          1481.0     95.5                       0.0
# 40      32305.0         32394.0     32.2                       0.0
# 51      24999.0         11199.0     40.1                       0.0
# 56       6028.0          1124.0     90.1                       0.0
#
#     delinq_amnt  mo_sin_old_il_acct  mo_sin_old_rev_tl_op  \
# 16          0.0               166.0                 295.0
# 38          0.0               157.0                 220.0
# 40          0.0               137.0                 119.0
# 51          0.0               133.0                 138.0
# 56          0.0               167.0                 111.0
#
#     mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  \
# 16                    3.0             2.0       0.0                   9.0
# 38                    0.0             0.0       4.0                  26.0
# 40                   24.0             9.0       2.0                  24.0
# 51                    4.0             4.0       1.0                   4.0
# 56                   46.0            18.0       0.0                  46.0
#
#     mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 16                       NaN                    2.0
# 38                       NaN                    0.0
# 40                       NaN                    9.0
# 51                      64.0                    2.0
# 56                       NaN                   18.0
#
#     mths_since_recent_revol_delinq  num_accts_ever_120_pd
# 16                             NaN                    0.0
# 38                             NaN                    4.0
# 40                             NaN                    0.0
# 51                            29.0                    0.0
# 56                             NaN                    0.0

# %%
features_to_be_removed.extend(['mo_sin_old_il_acct', 'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl', 'mths_since_recent_bc', 'mths_since_recent_bc_dlq', 'mths_since_recent_inq', 'mths_since_recent_revol_delinq', 'num_accts_ever_120_pd'])

# %% [markdown]
# #### 71 - 80 features

# %%
df.iloc[0:5, 65: 80]
# Out:
#     mths_since_recent_bc  mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 16                   9.0                       NaN                    2.0
# 38                  26.0                       NaN                    0.0
# 40                  24.0                       NaN                    9.0
# 51                   4.0                      64.0                    2.0
# 56                  46.0                       NaN                   18.0
#
#     mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 16                             NaN                    0.0             1.0
# 38                             NaN                    4.0             9.0
# 40                             NaN                    0.0             4.0
# 51                            29.0                    0.0             6.0
# 56                             NaN                    0.0             4.0
#
#     num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 16              4.0          2.0        3.0       17.0           12.0
# 38             11.0         10.0       11.0        8.0           14.0
# 40              4.0          5.0        6.0       24.0            6.0
# 51              8.0          6.0        8.0       10.0            9.0
# 56              4.0          4.0        6.0        8.0            4.0
#
#     num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m
# 16           16.0                  4.0      18.0               0.0
# 38           16.0                 11.0      17.0               0.0
# 40            8.0                  4.0       9.0               0.0
# 51           19.0                  8.0      13.0               0.0
# 56            9.0                  4.0       6.0               0.0

# %%
features_to_be_removed.extend(['num_actv_bc_tl', 'num_actv_rev_tl', 'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl', 'num_rev_accts', 'num_rev_tl_bal_gt_0', 'num_sats', 'num_tl_120dpd_2m'])

# %% [markdown]
# #### 81 - 90 features

# %%
df.iloc[0:5, 75: 90]
# Out:
#     num_op_rev_tl  num_rev_accts  num_rev_tl_bal_gt_0  num_sats  \
# 16           12.0           16.0                  4.0      18.0
# 38           14.0           16.0                 11.0      17.0
# 40            6.0            8.0                  4.0       9.0
# 51            9.0           19.0                  8.0      13.0
# 56            4.0            9.0                  4.0       6.0
#
#     num_tl_120dpd_2m  num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  \
# 16               0.0           0.0                 0.0                 6.0
# 38               0.0           0.0                 0.0                 1.0
# 40               0.0           0.0                 0.0                 1.0
# 51               0.0           0.0                 0.0                 3.0
# 56               0.0           0.0                 0.0                 0.0
#
#     pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 16           100.0               0.0                   1.0        0.0
# 38            87.1             100.0                   0.0        0.0
# 40            94.1              20.0                   1.0        0.0
# 51            66.7              16.7                   0.0        0.0
# 56            94.4              75.0                   0.0        0.0
#
#     tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit
# 16          93599.0            36506.0          9000.0
# 38         424707.0            81780.0         32700.0
# 40         374071.0            48682.0         47800.0
# 51         411827.0            68390.0         18700.0
# 56          52113.0            36168.0         11400.0

# %%
features_to_be_removed.extend(['num_tl_30dpd', 'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq', 'percent_bc_gt_75', 'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit'])

# %% [markdown]
# ### 91 to rest of the features

# %%
df.iloc[0:5, 85:]
# Out:
#     pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  total_bal_ex_mort  \
# 16                   1.0        0.0          93599.0            36506.0
# 38                   0.0        0.0         424707.0            81780.0
# 40                   1.0        0.0         374071.0            48682.0
# 51                   0.0        0.0         411827.0            68390.0
# 56                   0.0        0.0          52113.0            36168.0
#
#     total_bc_limit  total_il_high_credit_limit disbursement_method  \
# 16          9000.0                     55699.0                Cash
# 38         32700.0                     52309.0                Cash
# 40         47800.0                     38667.0                Cash
# 51         18700.0                     82927.0                Cash
# 56         11400.0                     40713.0                Cash
#
#    debt_settlement_flag  issue_month  issue_year  earliest_cr_year  \
# 16                    N            7        2017              1992
# 38                    N            7        2017              1998
# 40                    N            7        2017              2005
# 51                    N            7        2017              2005
# 56                    N            7        2017              2003
#
#     credit_history
# 16              25
# 38              19
# 40              12
# 51              12
# 56              14

# %%
df.disbursement_method.value_counts()
# Out:
# Cash         457716
# DirectPay        12
# Name: disbursement_method, dtype: int64

# %%
df.disbursement_method = df.disbursement_method.map(lambda x: 0 if x == 'Cash' else 1)

# %%
df.debt_settlement_flag.value_counts()
# Out:
# N    449510
# Y      8218
# Name: debt_settlement_flag, dtype: int64

# %%
df.debt_settlement_flag = df.debt_settlement_flag.map(lambda x: 0 if x == 'N' else 1)

# %%
features_to_be_removed.extend(['debt_settlement_flag', 'total_il_high_credit_limit'])

# %% [markdown]
# ### Removed _ features

# %%
print(features_to_be_removed)
# Out:
# ['emp_title', 'id', 'url', 'title', 'zip_code', 'issue_d', 'mths_since_last_delinq', 'mths_since_last_record', 'inq_last_6mths', 'mths_since_last_delinq', 'mths_since_last_record', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries', 'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt', 'last_credit_pull_d', 'last_fico_range_high', 'last_fico_range_low', 'collections_12_mths_ex_med', 'mths_since_last_major_derog', 'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'total_rev_hi_lim', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util', 'chargeoff_within_12_mths', 'delinq_amnt', 'mo_sin_old_il_acct', 'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl', 'mths_since_recent_bc', 'mths_since_recent_bc_dlq', 'mths_since_recent_inq', 'mths_since_recent_revol_delinq', 'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_actv_rev_tl', 'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl', 'num_rev_accts', 'num_rev_tl_bal_gt_0', 'num_sats', 'num_tl_120dpd_2m', 'num_tl_30dpd', 'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq', 'percent_bc_gt_75', 'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit', 'debt_settlement_flag', 'total_il_high_credit_limit']

# %%
len(set(features_to_be_removed))
# Out:
# 61

# %% [markdown]
# ### Drop selected features

# %%
df_selected = df.drop(list(set(features_to_be_removed)), axis = 1)

# %%
df_selected.shape
# Out:
# (457728, 36)

# %%
df_dtypes = pd.merge(df_selected.isnull().sum(axis = 0).sort_values().to_frame('missing_value').reset_index(),
         df_selected.dtypes.to_frame('feature_type').reset_index(),
         on = 'index',
         how = 'inner')

# %%
df_dtypes.sort_values(['missing_value', 'feature_type'])
# Out:
#                    index  missing_value feature_type
# 13           issue_month              0         int8
# 6    initial_list_status              0        int64
# 8       application_type              0        int64
# 12   disbursement_method              0        int64
# 14            issue_year              0        int64
# 16      earliest_cr_year              0        int64
# 18            emp_length              0        int64
# 21                  term              0        int64
# 26        credit_history              0        int64
# 29   verification_status              0        int64
# 30           loan_status              0        int64
# 22              int_rate              0      float32
# 0              loan_amnt              0      float64
# 1        fico_range_high              0      float64
# 2               open_acc              0      float64
# 3                pub_rec              0      float64
# 4              revol_bal              0      float64
# 5              total_acc              0      float64
# 7         fico_range_low              0      float64
# 9               mort_acc              0      float64
# 10  pub_rec_bankruptcies              0      float64
# 11             tax_liens              0      float64
# 15  acc_open_past_24mths              0      float64
# 19           funded_amnt              0      float64
# 20       funded_amnt_inv              0      float64
# 23           installment              0      float64
# 28            annual_inc              0      float64
# 33           delinq_2yrs              0      float64
# 17      earliest_cr_line              0       object
# 24                 grade              0       object
# 25             sub_grade              0       object
# 27        home_ownership              0       object
# 31               purpose              0       object
# 32            addr_state              0       object
# 34                   dti             21      float64
# 35            revol_util            223      float32

# %%
df_selected.dropna(inplace=True)

# %%
df_selected.shape
# Out:
# (457484, 36)

# %%
df_selected.drop('earliest_cr_line', axis = True, inplace=True)

# %%
df_selected.purpose.value_counts()
# Out:
# debt_consolidation    276479
# credit_card           102340
# home_improvement       27591
# other                  22073
# major_purchase          8246
# medical                 4776
# small_business          4204
# car                     3959
# moving                  2950
# vacation                2751
# house                   1835
# renewable_energy         268
# wedding                   11
# educational                1
# Name: purpose, dtype: int64

# %%
df_selected.purpose = df_selected.purpose.astype("category", categories=np.unique(df_selected.purpose)).cat.codes

# %%
df_selected.purpose.value_counts()
# Out:
# 2     276479
# 1     102340
# 4      27591
# 9      22073
# 6       8246
# 7       4776
# 11      4204
# 0       3959
# 8       2950
# 12      2751
# 5       1835
# 10       268
# 13        11
# 3          1
# Name: purpose, dtype: int64

# %%
df_selected.home_ownership = df_selected.home_ownership.astype("category", categories = np.unique(df_selected.home_ownership)).cat.codes

# %%
df_selected.home_ownership.value_counts()
# Out:
# 1    228337
# 4    181232
# 3     47839
# 0        75
# 2         1
# Name: home_ownership, dtype: int64

# %%
df_selected.grade = df_selected.grade.astype("category", categories = np.unique(df_selected.grade)).cat.codes

# %%
df_selected.grade.value_counts()
# Out:
# 2    129897
# 1    123032
# 0     75537
# 3     74262
# 4     38812
# 5     12501
# 6      3443
# Name: grade, dtype: int64

# %%
df_selected.sub_grade = df_selected.sub_grade.astype("category", categories = np.unique(df_selected.sub_grade)).cat.codes

# %%
df_selected.sub_grade.value_counts()
# Out:
# 10    27774
# 11    27365
# 9     26514
# 12    26361
# 8     26205
# 13    25596
# 7     25556
# 6     22881
# 14    22801
# 4     22731
# 5     21876
# 15    19234
# 3     17541
# 16    16039
# 17    14551
# 18    13390
# 2     11969
# 1     11707
# 0     11589
# 19    11048
# 20    10361
# 21     9170
# 22     7532
# 23     6255
# 24     5494
# 25     3989
# 26     2802
# 27     2447
# 28     1882
# 29     1381
# 30     1121
# 31      863
# 32      603
# 33      461
# 34      395
# Name: sub_grade, dtype: int64

# %%
df_selected.addr_state = df_selected.addr_state.astype("category", categories = np.unique(df_selected.addr_state)).cat.codes

# %%
df_selected.sub_grade.value_counts()
# Out:
# 10    27774
# 11    27365
# 9     26514
# 12    26361
# 8     26205
# 13    25596
# 7     25556
# 6     22881
# 14    22801
# 4     22731
# 5     21876
# 15    19234
# 3     17541
# 16    16039
# 17    14551
# 18    13390
# 2     11969
# 1     11707
# 0     11589
# 19    11048
# 20    10361
# 21     9170
# 22     7532
# 23     6255
# 24     5494
# 25     3989
# 26     2802
# 27     2447
# 28     1882
# 29     1381
# 30     1121
# 31      863
# 32      603
# 33      461
# 34      395
# Name: sub_grade, dtype: int64

# %%
df_selected.columns
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'emp_length', 'home_ownership',
#        'annual_inc', 'verification_status', 'loan_status', 'purpose',
#        'addr_state', 'dti', 'delinq_2yrs', 'fico_range_low', 'fico_range_high',
#        'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'application_type', 'acc_open_past_24mths',
#        'mort_acc', 'pub_rec_bankruptcies', 'tax_liens', 'disbursement_method',
#        'issue_month', 'issue_year', 'earliest_cr_year', 'credit_history'],
#       dtype='object')

# %% [markdown]
# ### Save selected features

# %%
df_selected.to_csv('./data/df_selected.csv', index = False)
